# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Q1

list=[5,6,9,3,2,7]
n=5
max=list[0]
min=list[0]

for i in range(n):
    if max<list[i] : max=list[i]
print("MAXIMUM : ",max)

for i in range(n):
    if min>list[i] : min=list[i]
print("MINIMUM : ",min)
# Out:
# MAXIMUM :  9
# MINIMUM :  2

# %%
#Q2

def is_palindrome(text: str) -> bool:
    cleaned_text = text.lower().replace(" ", "")
    return cleaned_text == cleaned_text[::-1]

# %%
#Q3

list=[1,5,3,9,7]
var=2
for i in range(len(list)):
    for j in range(i+1,len(list)) :
        if abs(list[i]-list[j])==var:
            print("(",list[i],",",list[j],")")
# Out:
# ( 1 , 3 )
# ( 5 , 3 )
# ( 5 , 7 )
# ( 9 , 7 )

# %%
#Q4

data = {
'Ticker': ['RELIANCE', 'TCS', 'INFY', 'HDFCBANK', 'WIPRO'],
'Price': [2850.5, 3900.0, 1500.75, 1650.0, 420.3],
'Volume': [1200000, 850000, 1100000, 950000, 700000],
'Sector': ['Energy', 'IT', 'IT', 'Finance', 'IT']
}

df=pd.DataFrame(data)

#a)

print("Shape : \n",df.shape)
print("First Three Rows :\n",df.head(3))

#b)

print("Sector = IT\n",df[df["Sector"]=="IT"])

#c)

df["Market_Cap_Proxy"]=df["Price"]*df["Volume"]

#d)

print("Market_Cap_Proxy_Descending :\n",df.sort_values(by='Market_Cap_Proxy', ascending=False))





#Q5

#a)

print("Mean Price :\n",df["Price"].mean())

#b)

print("Total Volume of IT Sector :\n",df[df["Sector"]=="IT"]["Volume"].sum())

#c)

print(df.loc[df['Market_Cap_Proxy'].idxmax(), 'Ticker'])
# Out:
# Shape :
#  (5, 4)
# First Three Rows :
#       Ticker    Price   Volume  Sector
# 0  RELIANCE  2850.50  1200000  Energy
# 1       TCS  3900.00   850000      IT
# 2      INFY  1500.75  1100000      IT
# Sector = IT
#    Ticker    Price   Volume Sector
# 1    TCS  3900.00   850000     IT
# 2   INFY  1500.75  1100000     IT
# 4  WIPRO   420.30   700000     IT
# Market_Cap_Proxy_Descending :
#       Ticker    Price   Volume   Sector  Market_Cap_Proxy
# 0  RELIANCE  2850.50  1200000   Energy      3.420600e+09
# 1       TCS  3900.00   850000       IT      3.315000e+09
# 2      INFY  1500.75  1100000       IT      1.650825e+09
# 3  HDFCBANK  1650.00   950000  Finance      1.567500e+09
# 4     WIPRO   420.30   700000       IT      2.942100e+08
# Mean Price :
#  2064.31
# Total Volume of IT Sector :
#  2650000
# RELIANCE

# %%
#Q6

scores = np.array([45, 82, 76, 55, 90, 38, 67, 71])

#a)

print(np.mean(scores))
print(np.median(scores))
print(np.std(scores))

#b)

min=np.min(scores)
max=np.max(scores)
print((scores-min)/(max-min))

#c)

print(np.where(scores>np.mean(scores))[0])
# Out:
# 65.5
# 69.0
# 16.963195453687373
# [0.13461538 0.84615385 0.73076923 0.32692308 1.         0.
#  0.55769231 0.63461538]
# [1 2 4 6 7]

# %%
#Q7

mean = 0.0008
std = 0.015
dr = np.random.normal(loc=mean, scale=std, size=252)

#a)

ip = 100
ps = ip * np.cumprod(1 + dr)

#b)

plt.figure(figsize=(10, 5))
plt.plot(ps, label="Simulated Stock Price", color="blue", linewidth=2)
plt.title("Simulated Stock Price Series Over 252 Trading Days")
plt.xlabel("Trading Days")
plt.ylabel("Price ($)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()

#c)

print(ps[-1])
print(np.max(ps))
rm = np.maximum.accumulate(ps)
dd = (ps - rm) / rm
print(np.min(dd))
# Out:
# 78.09139055696666
# 107.95927631810886
# -0.2766588178410402

# %%
#Q8

months = ['Jan','Feb','Mar','Apr','May','Jun',
'Jul','Aug','Sep','Oct','Nov','Dec']
year1 =np.array ([42, 45, 50, 48, 55, 60, 58, 63, 67, 70, 75, 80])
year2 = np.array([52, 49, 58, 61, 66, 71, 68, 74, 79, 83, 88, 95])
colors = ['green' if diff >= 0 else 'red' for diff in year1-year2]
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
ax1.plot(months, year1, label='Year 1', color='tab:blue', marker='o', linewidth=2)
ax1.plot(months, year2, label='Year 2', color='tab:orange', marker='s', linewidth=2)
ax1.set_title('Monthly Revenue Comparison (in Lakhs)', fontsize=14, fontweight='bold')
ax1.set_ylabel('Revenue (Lakhs)', fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.5)
ax1.legend(fontsize=11)
ax2.bar(months, year1-year2, color=colors, edgecolor='black', alpha=0.8)
ax2.axhline(0, color='black', linewidth=1, linestyle='-')  # Add a baseline at zero
ax2.set_title('Month-by-Month Revenue Growth (Year 2 - Year 1)', fontsize=12, fontweight='bold')
ax2.set_xlabel('Months', fontsize=12)
ax2.set_ylabel('Difference (Lakhs)', fontsize=12)
ax2.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
#Q9

df = pd.DataFrame({
'Day': range(1, 11),
'Price': [100, 103, np.nan, 108, 107, np.nan, 112, 115, np.nan, 120],
'Volume': [500, 520, 510, np.nan, 530, 545, np.nan, 560, 570, 580]
})

print(df.isna().sum())

df['Price'] = df['Price'].ffill()
vm = df['Volume'].mean()
df['Volume'] = df['Volume'].fillna(vm)

df['Return'] = df['Price'].pct_change() * 100
print(df)
# Out:
# Day       0
# Price     3
# Volume    2
# dtype: int64
#    Day  Price   Volume    Return
# 0    1  100.0  500.000       NaN
# 1    2  103.0  520.000  3.000000
# 2    3  103.0  510.000  0.000000
# 3    4  108.0  539.375  4.854369
# 4    5  107.0  530.000 -0.925926
# 5    6  107.0  545.000  0.000000
# 6    7  112.0  539.375  4.672897
# 7    8  115.0  560.000  2.678571
# 8    9  115.0  570.000  0.000000
# 9   10  120.0  580.000  4.347826

# %%
#Q10

np.random.seed(42)
returns = np.random.multivariate_normal(
mean=[0.0005, 0.0008, 0.0003],
cov=[[0.0004, 0.0001, 0.00005],
[0.0001, 0.0006, 0.00008],
[0.00005, 0.00008, 0.0003]],
size=200
)
prices = 100 * np.cumprod(1 + returns, axis=0)

dfp=pd.DataFrame(prices,columns=['Asset_A', 'Asset_B', 'Asset_C'])


dfp['Portfolio'] = dfp[['Asset_A', 'Asset_B', 'Asset_C']].mean(axis=1)

plt.figure(figsize=(11, 6))
plt.plot(dfp['Asset_A'], label='Asset A', color='tab:blue', alpha=0.7)
plt.plot(dfp['Asset_B'], label='Asset B', color='tab:orange', alpha=0.7)
plt.plot(dfp['Asset_C'], label='Asset C', color='tab:green', alpha=0.7)

dfr=pd.DataFrame(returns,columns=['Asset_A', 'Asset_B', 'Asset_C'])
corrm=dfr.corr()
print(corrm)



plt.plot(dfp['Portfolio'], label='Equally-Weighted Portfolio', 
         color='black', linewidth=2.5, linestyle='--')

plt.title('Simulated Asset & Portfolio Price Series Over 200 Days', fontsize=14, fontweight='bold')
plt.xlabel('Trading Days', fontsize=12)
plt.ylabel('Price ($)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11, loc='upper left')

plt.tight_layout()
plt.show()
# Out:
#           Asset_A   Asset_B   Asset_C
# Asset_A  1.000000  0.087809  0.064399
# Asset_B  0.087809  1.000000  0.198940
# Asset_C  0.064399  0.198940  1.000000
